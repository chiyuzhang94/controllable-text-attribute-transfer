# %%
import time
import argparse
import math
import os
import torch
import torch.nn as nn
from torch import optim
import numpy
import matplotlib
from matplotlib import pyplot as plt


# Import your model files.
from model import make_model, Classifier, NoamOpt, LabelSmoothing, fgim_attack
from data import prepare_data, non_pair_data_loader, get_cuda, pad_batch_seuqences, load_human_answer,\
    id2text_sentence, to_var, calc_bleu

# %%
from attributedict.collections import AttributeDict

# %%
args = AttributeDict({'id_pad':0, 'id_unk':1, "id_bos" : 2, 'id_eos':3,'task':'dialect',\
                     'word_to_id_file': '', 'data_path' :'../../data/uae-eg/processed_files/', \
                     'word_dict_max_num' :5, 'batch_size' :128, 'max_sequence_length' :64, 'num_layers_AE':2,
                     'transformer_model_size':256, 'transformer_ff_size' : 1024,'latent_size': 256, \
                     'word_dropout': 1.0, 'embedding_dropout':0.5,'learning_rate':0.001, 'label_size':1})

# %%
args.id_bos
# Out:
# 2

# %%
args.if_load_from_checkpoint = True
args.checkpoint_name = "1588047455"

# %%
def add_log(ss):
    now_time = time.strftime("[%Y-%m-%d %H:%M:%S]: ", time.localtime())
    print(now_time + ss)
    with open(args.log_file, 'a') as f:
        f.write(now_time + str(ss) + '\n')
    return


def add_output(ss):
    with open(args.output_file, 'a') as f:
        f.write(str(ss) + '\n')
    return


def preparation():
    # set model save path
    if args.if_load_from_checkpoint:
        timestamp = args.checkpoint_name
    else:
        timestamp = str(int(time.time()))
        print("create new model save path: %s" % timestamp)
    args.current_save_path = 'save/%s/' % timestamp
    args.log_file = args.current_save_path + time.strftime("log_%Y_%m_%d_%H_%M_%S.txt", time.localtime())
    args.output_file = args.current_save_path + time.strftime("output_%Y_%m_%d_%H_%M_%S.txt", time.localtime())
    print("create log file at path: %s" % args.log_file)

    if os.path.exists(args.current_save_path):
        add_log("Load checkpoint model from Path: %s" % args.current_save_path)
    else:
        os.makedirs(args.current_save_path)
        add_log("Path: %s is created" % args.current_save_path)

    # set task type
    if args.task == 'yelp':
        args.data_path = '../../data/yelp/processed_files/'
    elif args.task == 'amazon':
        args.data_path = '../../data/amazon/processed_files/'
    elif args.task == 'dialect':
        args.data_path = '../../data/uae-eg/processed_files/'
    elif args.task == 'imagecaption':
        pass
    else:
        raise TypeError('Wrong task type!')

    # prepare data
    args.id_to_word, args.vocab_size, \
    args.train_file_list, args.train_label_list = prepare_data(
        data_path=args.data_path, max_num=args.word_dict_max_num, task_type=args.task
    )
    return

# %%
preparation()

ae_model = get_cuda(make_model(d_vocab=args.vocab_size,
                               N=args.num_layers_AE,
                               d_model=args.transformer_model_size,
                               latent_size=args.latent_size,
                               d_ff=args.transformer_ff_size,
))
dis_model = get_cuda(Classifier(latent_size=args.latent_size, output_size=args.label_size))
# Out:
# create log file at path: save/1588047455/log_2020_04_28_17_15_21.txt
# [2020-04-28 17:15:21]: Load checkpoint model from Path: save/1588047455/
# prepare data ...
# Load word-dict with 41286 size and 5 max_num.

# %%
ae_model.load_state_dict(torch.load(args.current_save_path + 'ae_model_params.pkl'))
dis_model.load_state_dict(torch.load(args.current_save_path + 'dis_model_params.pkl'))
# Out:
# <All keys matched successfully>

# %%
def eval_iters(ae_model, dis_model):
    eval_data_loader = non_pair_data_loader(
        batch_size=1, id_bos=args.id_bos,
        id_eos=args.id_eos, id_unk=args.id_unk,
        max_sequence_length=args.max_sequence_length, vocab_size=args.vocab_size
    )
    eval_file_list = [
        args.data_path + 'dialect_dev.uae',
        args.data_path + 'dialect_dev.eg',
    ]
    eval_label_list = [
        [0],
        [1],
    ]
    eval_data_loader.create_batches(eval_file_list, eval_label_list, if_shuffle=False)
#     gold_ans = load_human_answer(args.data_path)
#     assert len(gold_ans) == eval_data_loader.num_batch

    count = 0
    add_log("Start eval process.")
    ae_model.eval()
    dis_model.eval()
    for it in range(eval_data_loader.num_batch):
        batch_sentences, tensor_labels, \
        tensor_src, tensor_src_mask, tensor_tgt, tensor_tgt_y, \
        tensor_tgt_mask, tensor_ntokens = eval_data_loader.next_batch()

        print("------------%d------------" % it)
        print("origin_input","\n label is ", tensor_labels)
        print(id2text_sentence(tensor_tgt_y[0], args.id_to_word))

        latent, out = ae_model.forward(tensor_src, tensor_tgt, tensor_src_mask, tensor_tgt_mask)
        generator_text = ae_model.greedy_decode(latent,
                                                max_len=args.max_sequence_length,
                                                start_id=args.id_bos)
#         print("------------------------")
#         print("autoencoder output:")
#         print(id2text_sentence(generator_text[0], args.id_to_word))

        # Define target label
        target = get_cuda(torch.tensor([[1.0]], dtype=torch.float))
        if tensor_labels[0].item() > 0.5:
            target = get_cuda(torch.tensor([[0.0]], dtype=torch.float))
        print("target_labels", target)

        modify_text = fgim_attack(dis_model, latent, target, ae_model, args.max_sequence_length, args.id_bos,
                                        id2text_sentence, args.id_to_word, '')
        add_output(modify_text)
        count += 1
        if count >= 10:
            break
    return

# %%
eval_iters(ae_model, dis_model)
# Out:
# Load data from ../../data/uae-eg/processed_files/dialect_dev.uae ../../data/uae-eg/processed_files/dialect_dev.eg !
# Create 59225 batches with 1 batch_size
# [2020-04-28 18:39:47]: Start eval process.
# ------------0------------
# user الانضباط <UNK> hash num الف درهم <UNK> له <UNK> <UNK> <UNK> <UNK> في مباراه راس الخيمه
# origin_labels tensor([[0.]], device='cuda:0')
# user hash ناديكم <UNK> num الف درهم له <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه مباراه دبي محتاج حسابات
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.0787 |
# user hash ناديكم <UNK> num الف درهم له <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه مباراه دبي محتاج حسابات
# epsilon: 1.8
# | It  2 | dis model pred 0.2038 |
# user hash <UNK> ناديكم num له الف درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وبعد مباراه واحده
# epsilon: 1.62
# | It  3 | dis model pred 0.3545 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.4702 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.6035 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 3.0
# | It  1 | dis model pred 0.0787 |
# user hash <UNK> ناديكم num له الف درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وبعد مباراه واحده
# epsilon: 2.7
# | It  2 | dis model pred 0.2912 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 2.43
# | It  3 | dis model pred 0.4845 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.7016 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه النتيجه hash
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.8516 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه النتيجه hash
# epsilon: 4.0
# | It  1 | dis model pred 0.0787 |
# user hash <UNK> ناديكم num له الف درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وبعد مباراه واحده
# epsilon: 3.6
# | It  2 | dis model pred 0.3819 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 3.24
# | It  3 | dis model pred 0.6109 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه سلمان العوده
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.8835 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه سلمان العوده
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.9322 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه سلمان العوده
# epsilon: 5.0
# | It  1 | dis model pred 0.0787 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 4.5
# | It  2 | dis model pred 0.4793 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه سلمان العوده
# epsilon: 4.05
# | It  3 | dis model pred 0.8899 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان ماتش النجاح دلوقتي
# epsilon: 3.645
# | It  4 | dis model pred 0.9464 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان ماتش النجاح دلوقتي
# epsilon: 3.2805
# | It  5 | dis model pred 0.9588 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان ماتش النجاح دلوقتي
# epsilon: 6.0
# | It  1 | dis model pred 0.0787 |
# user hash <UNK> الفيفا num الف له درهم <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه hash
# epsilon: 5.4
# | It  2 | dis model pred 0.5949 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه سلمان العوده
# epsilon: 4.86
# | It  3 | dis model pred 0.9533 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان ماتش النجاح دلوقتي
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.9668 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان ماتش النجاح دلوقتي
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.9731 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان ماتش النجاح دلوقتي
# epsilon: 7.0
# | It  1 | dis model pred 0.0787 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه سلمان العوده
# epsilon: 6.3
# | It  2 | dis model pred 0.7125 |
# hash المحكمه <UNK> num قال له الف <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان <UNK> مباراه اكبر اتصالات
# epsilon: 5.67
# | It  3 | dis model pred 0.9597 |
# hash المحكمه <UNK> num قال له الف <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان <UNK> مباراه اكبر اتصالات
# epsilon: 5.103
# | It  4 | dis model pred 0.9713 |
# hash المحكمه <UNK> num قال له الف <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان <UNK> مباراه اكبر اتصالات
# epsilon: 4.5927
# | It  5 | dis model pred 0.9767 |
# hash المحكمه <UNK> num قال له الف <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه علشان <UNK> مباراه اكبر اتصالات
# epsilon: 8.0
# | It  1 | dis model pred 0.0787 |
# hash وزاره <UNK> num مليون فقط <UNK> له الف <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه وفي اي حاجه سلمان العوده
# epsilon: 7.2
# | It  2 | dis model pred 0.8126 |
# hash المحكمه <UNK> num الف hash له <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> في راس الخيمه عشان مباراه اكبر hash
# epsilon: 6.48
# | It  3 | dis model pred 0.9721 |
# hash المحكمه <UNK> num قال هناك الف <UNK> <UNK> <UNK> <UNK> <UNK> له <UNK> في راس الخيمه انك عايزين نطلع hash
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.9783 |
# hash المحكمه <UNK> num قال هناك الف <UNK> <UNK> <UNK> <UNK> <UNK> له <UNK> في راس الخيمه انك عايزين نطلع hash
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.9814 |
# hash المحكمه <UNK> num قال هناك الف <UNK> <UNK> <UNK> <UNK> <UNK> له <UNK> في راس الخيمه انك عايزين نطلع فيه مطار
# ------------1------------
# بعض البشر يغرك بصدق الاحساس num وبعض البشر hash وقلبه يحبك
# origin_labels tensor([[0.]], device='cuda:0')
# ان البشر تقع وسط الكلام بصدق num بس هناك بشر اللي يجبرك به num ابو زايد وزينه الساعه
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.1535 |
# ان البشر تسقط hash النعيم num كثر الاخوان او الصافي حتي يشبه الجميع <UNK> الصديق كيف يحبك وقلبه num
# epsilon: 1.8
# | It  2 | dis model pred 0.3967 |
# ان البشر تسقط hash النعيم num كثر الاخوان او الصافي حتي يشبه الجميع <UNK> الصديق كيف يحبك وقلبه num
# epsilon: 1.62
# | It  3 | dis model pred 0.4726 |
# ان البشر تسقط hash النعيم num كثر الاخوان او الصافي حتي يشبه الجميع <UNK> الصديق كيف يحبك وقلبه num
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.5144 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني بوظبي بوظبي بتخاف عنه انت وهو العزيز مجرد
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.5511 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني بوظبي بوظبي بتخاف عنه هو مجرد وجه نفسه
# epsilon: 3.0
# | It  1 | dis model pred 0.1535 |
# ان البشر تسقط hash النعيم num كثر الاخوان او الصافي حتي يشبه الجميع <UNK> الصديق كيف يحبك وقلبه num
# epsilon: 2.7
# | It  2 | dis model pred 0.4768 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني بوظبي يضايقك _ فما هو يحبك اول خلقه
# epsilon: 2.43
# | It  3 | dis model pred 0.5464 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني بوظبي يضايقك _ فما هو يحبك اول خلقه
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.5927 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني الصافي لا يخلق شي اليك انسان
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.6320 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني الصافي لا يخلق شي اليك انسان
# epsilon: 4.0
# | It  1 | dis model pred 0.1535 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني بوظبي يضايقك _ فما هو يحبك اول خلقه
# epsilon: 3.6
# | It  2 | dis model pred 0.5328 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني الصافي لا يخلق شي اليك انسان
# epsilon: 3.24
# | It  3 | dis model pred 0.6090 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني الصافي لا يخلق شي اليك انسان
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.6703 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني الصافي لا يضر فيك من امه خالد توفيق
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.7049 |
# ان البشر تسقط hash النعيم كثر num ولكن البعض <UNK> عيني الصافي لا يضر فيك من امه خالد توفيق
# epsilon: 5.0
# | It  1 | dis model pred 0.1535 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك اشخاصا <UNK> راشق فيه وجه الشخص وهو احبه
# epsilon: 4.5
# | It  2 | dis model pred 0.5877 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 4.05
# | It  3 | dis model pred 0.6523 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 3.645
# | It  4 | dis model pred 0.7182 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 3.2805
# | It  5 | dis model pred 0.7457 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 6.0
# | It  1 | dis model pred 0.1535 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك اشخاصا <UNK> راشق فيه وجه الله سبحانه وهو المستعان
# epsilon: 5.4
# | It  2 | dis model pred 0.6184 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 4.86
# | It  3 | dis model pred 0.6926 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.7398 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.7630 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 7.0
# | It  1 | dis model pred 0.1535 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك اشخاصا <UNK> راشق فيه وهو وجه الشخص اليكم
# epsilon: 6.3
# | It  2 | dis model pred 0.6270 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك اشخاصا <UNK> راشق فيه وهو وجه الشخص اليكم
# epsilon: 5.67
# | It  3 | dis model pred 0.7060 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 5.103
# | It  4 | dis model pred 0.7514 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 4.5927
# | It  5 | dis model pred 0.7811 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 8.0
# | It  1 | dis model pred 0.1535 |
# عندما يحبك بصدق الناس وبعض البشر hash num ولكن يزرع الله كثيرا الدور ل بہ حكمه وقلبه num
# epsilon: 7.2
# | It  2 | dis model pred 0.6436 |
# عندما يحبك بصدق الناس وبعض البشر hash num ولكن من يزرع المطر القران كده بك وهو علي التقدم
# epsilon: 6.48
# | It  3 | dis model pred 0.7183 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.7664 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.7942 |
# ان البشر تسقط hash النعيم بصدق num ولكن هناك موقف تحرر المحبه كان ربك دائما فانه يتالم
# ------------2------------
# الي <UNK> لفتره <UNK> <UNK> الناس والناس يدرون فقط <UNK>
# origin_labels tensor([[0.]], device='cuda:0')
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس راضيا عني بانتظار <UNK> num هل <UNK> الناس فقط num العليا
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.4200 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس راضيا عني بانتظار <UNK> num هل <UNK> الناس ده يمشي <UNK> جدا
# epsilon: 1.8
# | It  2 | dis model pred 0.5136 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 1.62
# | It  3 | dis model pred 0.5904 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.6836 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.7287 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 3.0
# | It  1 | dis model pred 0.4200 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 2.7
# | It  2 | dis model pred 0.5595 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 2.43
# | It  3 | dis model pred 0.7280 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.7979 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.8415 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 4.0
# | It  1 | dis model pred 0.4200 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 3.6
# | It  2 | dis model pred 0.5986 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 3.24
# | It  3 | dis model pred 0.7907 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس الهادي او <UNK> فقط هموت ولا الي <UNK> كسر ويهه حلوه
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.8589 |
# <UNK> الي <UNK> <UNK> <UNK> الناس مو <UNK> <UNK> <UNK> ادني واحده بس عن فريقك <UNK> جداا
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.9012 |
# <UNK> الي <UNK> <UNK> <UNK> الناس مو <UNK> <UNK> <UNK> ادني واحده بس عن فريقك <UNK> جداا
# epsilon: 5.0
# | It  1 | dis model pred 0.4200 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا num تحسب انهم <UNK> <UNK> الي فاتت لا بعد <UNK> لبيع المياه
# epsilon: 4.5
# | It  2 | dis model pred 0.6127 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 4.05
# | It  3 | dis model pred 0.8298 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس الهادي او <UNK> فقط هموت ولا الي <UNK> كسر ويهه حلوه
# epsilon: 3.645
# | It  4 | dis model pred 0.8930 |
# <UNK> الي <UNK> <UNK> <UNK> الناس مو <UNK> <UNK> <UNK> ادني واحده بس عن فريقك <UNK> جداا
# epsilon: 3.2805
# | It  5 | dis model pred 0.9198 |
# <UNK> الي <UNK> <UNK> <UNK> الناس مو <UNK> <UNK> <UNK> ادني واحده بس عن فريقك <UNK> جداا
# epsilon: 6.0
# | It  1 | dis model pred 0.4200 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا num تحسب انهم <UNK> <UNK> كده واهلك انفسنا لكن <UNK>
# epsilon: 5.4
# | It  2 | dis model pred 0.6240 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 4.86
# | It  3 | dis model pred 0.8816 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس الهادي او <UNK> فقط هموت ولا <UNK> الي الان لانها دعواتكم
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.9277 |
# <UNK> الي <UNK> <UNK> <UNK> الناس مو <UNK> <UNK> <UNK> ادني واحده بس عن فريقك <UNK> جداا
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.9428 |
# <UNK> الي <UNK> <UNK> <UNK> والناس <UNK> الناس ميديا انه تم <UNK> <UNK> قلبهم مو هتعرف ان <UNK> lt
# epsilon: 7.0
# | It  1 | dis model pred 0.4200 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا num تحسب انهم <UNK> <UNK> كده واهلك انفسنا لكن <UNK>
# epsilon: 6.3
# | It  2 | dis model pred 0.6376 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 5.67
# | It  3 | dis model pred 0.9207 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس بتاعك بس تغفر علشان <UNK> سنه بورسعيد <UNK> ف التجربه
# epsilon: 5.103
# | It  4 | dis model pred 0.9449 |
# <UNK> الي <UNK> <UNK> <UNK> الناس مو <UNK> <UNK> <UNK> ادني واحده بس عن <UNK> الزباله
# epsilon: 4.5927
# | It  5 | dis model pred 0.9556 |
# <UNK> الي <UNK> <UNK> <UNK> والناس <UNK> الناس ميديا انه تم <UNK> <UNK> سجاير بس اسال نفسك
# epsilon: 8.0
# | It  1 | dis model pred 0.4200 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا num تحسب انهم <UNK> <UNK> كده واهلك انفسنا لكن <UNK>
# epsilon: 7.2
# | It  2 | dis model pred 0.6509 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال الاوروبيه num
# epsilon: 6.48
# | It  3 | dis model pred 0.9407 |
# <UNK> الي <UNK> <UNK> <UNK> بعض الناس سريعا بس من كاتب <UNK> <UNK> الاعمال دي لكن تعبانه hash
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.9611 |
# <UNK> الي <UNK> <UNK> <UNK> ليه الناس ومش تحبہ <UNK> الوجع لان واحده بس <UNK> الذين مؤمنين بقي
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.9688 |
# <UNK> الي <UNK> <UNK> <UNK> ليه الناس ومش بتعمله كام <UNK> و <UNK> الحسين صعب طبعا
# ------------3------------
# <UNK> بعدين <UNK> هذه شيم <UNK>
# origin_labels tensor([[0.]], device='cuda:0')
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> اثبتت اللعبه ال num feeling sad
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.5104 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> رايي والايمان علي حب الذي <UNK> عيل
# epsilon: 1.8
# | It  2 | dis model pred 0.5953 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> رايي والايمان علي حب الذي <UNK> هه
# epsilon: 1.62
# | It  3 | dis model pred 0.6494 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم كانوا حيا
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.6836 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم كانوا حيا
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.7058 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم كانوا حيا
# epsilon: 3.0
# | It  1 | dis model pred 0.5104 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> رايي والايمان علي حب الذي <UNK> هه
# epsilon: 2.7
# | It  2 | dis model pred 0.6158 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم كانوا حيا
# epsilon: 2.43
# | It  3 | dis model pred 0.6820 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.7317 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.7659 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 4.0
# | It  1 | dis model pred 0.5104 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> رايي والايمان علي حب الذي <UNK> هه
# epsilon: 3.6
# | It  2 | dis model pred 0.6223 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 3.24
# | It  3 | dis model pred 0.7179 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.7761 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.8120 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 5.0
# | It  1 | dis model pred 0.5104 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> شئ انما <UNK> <UNK> بحياتي num
# epsilon: 4.5
# | It  2 | dis model pred 0.6283 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 4.05
# | It  3 | dis model pred 0.7545 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 3.645
# | It  4 | dis model pred 0.8135 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 3.2805
# | It  5 | dis model pred 0.8463 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه تخصص الشخص <UNK> ولكن num اخيرا <UNK> عليكم
# epsilon: 6.0
# | It  1 | dis model pred 0.5104 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> شئ انما <UNK> <UNK> بحياتي num
# epsilon: 5.4
# | It  2 | dis model pred 0.6347 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num سواء الرحمن <UNK> عن <UNK> num
# epsilon: 4.86
# | It  3 | dis model pred 0.7816 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num feeling sad
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.8389 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num feeling sad
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.8667 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num feeling sad
# epsilon: 7.0
# | It  1 | dis model pred 0.5104 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> <UNK> شئ انما <UNK> <UNK> بحياتي num
# epsilon: 6.3
# | It  2 | dis model pred 0.6415 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num سواء الرحمن <UNK> عن <UNK> num
# epsilon: 5.67
# | It  3 | dis model pred 0.8239 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num feeling sad
# epsilon: 5.103
# | It  4 | dis model pred 0.8674 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num feeling sad
# epsilon: 4.5927
# | It  5 | dis model pred 0.8882 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر لجان واحده <UNK> num اخيرا <UNK> شر
# epsilon: 8.0
# | It  1 | dis model pred 0.5104 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> <UNK> ولو اخاف <UNK> شئ num مصطفي البصري دا
# epsilon: 7.2
# | It  2 | dis model pred 0.6494 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num سواء الرحمن <UNK> عن <UNK> num
# epsilon: 6.48
# | It  3 | dis model pred 0.8203 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num feeling sad
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.8688 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر الندم <UNK> num feeling sad
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.8940 |
# <UNK> <UNK> بعدين <UNK> هذه الزلات <UNK> ولو فيه مؤتمر لجان واحده <UNK> num اخيرا <UNK> شر
# ------------4------------
# اقم الصلاه <UNK> الشمس الي غسق الليل وقران الفجر ان قران الفجر كان مشهودا ٧٨ سوره الاسراء hash
# origin_labels tensor([[0.]], device='cuda:0')
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.3724 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# epsilon: 1.8
# | It  2 | dis model pred 0.4097 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# epsilon: 1.62
# | It  3 | dis model pred 0.4332 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.4582 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله ٢ سوره الاسراء hash
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.4775 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 3.0
# | It  1 | dis model pred 0.3724 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# epsilon: 2.7
# | It  2 | dis model pred 0.4262 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# epsilon: 2.43
# | It  3 | dis model pred 0.4590 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.5004 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.5340 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 4.0
# | It  1 | dis model pred 0.3724 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# epsilon: 3.6
# | It  2 | dis model pred 0.4428 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله ٢ سوره الاسراء hash
# epsilon: 3.24
# | It  3 | dis model pred 0.4872 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.5475 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.5878 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 5.0
# | It  1 | dis model pred 0.3724 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله وكان ذلك كما ربياني صغيرا hash
# epsilon: 4.5
# | It  2 | dis model pred 0.4583 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 4.05
# | It  3 | dis model pred 0.5235 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 3.645
# | It  4 | dis model pred 0.5730 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 3.2805
# | It  5 | dis model pred 0.6265 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من اخيه كان قلبك قران الفجر نحن لهم يسبحون ٢ ان كان الغفله سوره الحديد hash
# epsilon: 6.0
# | It  1 | dis model pred 0.3724 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله ٢ سوره الاسراء hash
# epsilon: 5.4
# | It  2 | dis model pred 0.4736 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 4.86
# | It  3 | dis model pred 0.5611 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.6164 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.6709 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 7.0
# | It  1 | dis model pred 0.3724 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله ٢ سوره الاسراء hash
# epsilon: 6.3
# | It  2 | dis model pred 0.4896 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر بخير ٧٧ سوره الاسراء hash
# epsilon: 5.67
# | It  3 | dis model pred 0.5903 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 5.103
# | It  4 | dis model pred 0.6471 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 4.5927
# | It  5 | dis model pred 0.6949 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر شئ مبينا ٥٨ سوره الاسراء hash
# epsilon: 8.0
# | It  1 | dis model pred 0.3724 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من حفظها الله الاهلي كان الفجر قران الغفله ٢ سوره الاسراء hash
# epsilon: 7.2
# | It  2 | dis model pred 0.5060 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 6.48
# | It  3 | dis model pred 0.6165 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر الفوز حكيما واصيلا hash
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.6705 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر شئ مبينا ٥٨ سوره الاسراء hash
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.7203 |
# اقم الصلاه <UNK> الشمس الي بطون اثنين من يتبدل لكم الليل والنهار لو كان قران الفجر شئ مبينا ٥٨ سوره الاسراء hash
# ------------5------------
# اجمل النساء امراه سهرت و تعبت و ربت و اعطت دون مقابل num تدعي امي
# origin_labels tensor([[0.]], device='cuda:0')
# اجمل النوم تدعي لو رايت شهر و <UNK> و بالهوا عندها num انما اصبحت من يكره دون قصد تدعي امي num
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.6406 |
# اجمل النوم تدعي لو رايت شهر و <UNK> و بالهوا عندها num انما اصبحت من يكره دون قصد تدعي امي num
# epsilon: 1.8
# | It  2 | dis model pred 0.8010 |
# اجمل النوم تدعي لو رايت شهر و <UNK> و بالهوا عندها num انما اصبحت من يكره دون قصد فشخ num
# epsilon: 1.62
# | It  3 | dis model pred 0.8557 |
# رب تعبت تقف فيه و صوت و <UNK> عانقت اجل num و ؤالله احسن منكم ناس <UNK> امام فتاه ثقيله عليها
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.8793 |
# رب تعبت تقف فيه و صوت و <UNK> عانقت اجل num و ؤالله احسن منكم ناس <UNK> امام فتاه ثقيله عليها
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.8943 |
# رب تعبت تقف فيه و صوت و <UNK> عانقت اجل num و ؤالله احسن منكم ناس <UNK> امام فتاه ثقيله عليها
# epsilon: 3.0
# | It  1 | dis model pred 0.6406 |
# اجمل النوم تدعي لو رايت شهر و <UNK> و بالهوا عندها num انما اصبحت من يكره دون قصد فشخ num
# epsilon: 2.7
# | It  2 | dis model pred 0.8545 |
# رب تعبت تقف فيه و صوت و <UNK> عانقت اجل num و ؤالله احسن منكم ناس <UNK> امام فتاه ثقيله عليها
# epsilon: 2.43
# | It  3 | dis model pred 0.8925 |
# رب تعبت تقف فيه و صوت و <UNK> عانقت اجل num و ؤالله احسن فشخ اصبحت من نار السرير وانت ماتت
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.9122 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و تدخلون الجنه قبل مقابل المراه وهي كاتبه لكل شيء
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.9245 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و تدخلون الجنه قبل مقابل المراه وهي كاتبه لكل شيء
# epsilon: 4.0
# | It  1 | dis model pred 0.6406 |
# رب تعبت تقف فيه و صوت و <UNK> عانقت اجل num و ؤالله احسن منكم ناس <UNK> امام فتاه ثقيله عليها
# epsilon: 3.6
# | It  2 | dis model pred 0.8909 |
# رب تعبت تقف فيه و صوت و <UNK> عانقت اجل num و ؤالله احسن فشخ اصبحت من نار السرير وانت ماتت
# epsilon: 3.24
# | It  3 | dis model pred 0.9196 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و تدخلون الجنه قبل مقابل المراه وهي كاتبه لكل شيء
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.9363 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و تدخلون الجنه قبل مقابل المراه وهي كاتبه لكل شيء
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.9498 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 5.0
# | It  1 | dis model pred 0.6406 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و تدخلون الجنه قبل مقابل المراه وهي كاتبه لكل شيء
# epsilon: 4.5
# | It  2 | dis model pred 0.9191 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و تدخلون الجنه قبل مقابل المراه وهي كاتبه لكل شيء
# epsilon: 4.05
# | It  3 | dis model pred 0.9428 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 3.645
# | It  4 | dis model pred 0.9591 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 3.2805
# | It  5 | dis model pred 0.9662 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها معقوله فيه
# epsilon: 6.0
# | It  1 | dis model pred 0.6406 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و تدخلون الجنه قبل مقابل المراه وهي كاتبه لكل شيء
# epsilon: 5.4
# | It  2 | dis model pred 0.9450 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 4.86
# | It  3 | dis model pred 0.9639 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.9702 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.9737 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 7.0
# | It  1 | dis model pred 0.6406 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 6.3
# | It  2 | dis model pred 0.9626 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 5.67
# | It  3 | dis model pred 0.9714 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 5.103
# | It  4 | dis model pred 0.9755 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 4.5927
# | It  5 | dis model pred 0.9782 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 8.0
# | It  1 | dis model pred 0.6406 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 7.2
# | It  2 | dis model pred 0.9731 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 6.48
# | It  3 | dis model pred 0.9774 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> عانقت نفسك num و عندكو تعلم جرح ام غيرها num شكلها لوحده
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.9802 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> ندامه و عايز num من انها قايله ليها فكره الورد <UNK> بالمره
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.9821 |
# اكتر قلبي بيجيب احلام و تعبت و <UNK> ندامه و عايز num من انها قايله ليها فكره الورد <UNK> بالمره
# ------------6------------
# خيره الله تبقي فوق كل وجع ل يهمس لك قلبك كفاك الله شيئا تحبه كي لا يمسك ضر كفاك كي ينبت لك فرحا اكبر واجمل
# origin_labels tensor([[0.]], device='cuda:0')
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك شكثر ان يعجبني تحبه كي تخيب لك عند الله ﮩ
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.0277 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك شكثر ان يعجبني تحبه كي تخيب لك عند الله لابن القيم
# epsilon: 1.8
# | It  2 | dis model pred 0.0514 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني عند التقدم والا كفاك اللہ ان ستبقي اسمعك
# epsilon: 1.62
# | It  3 | dis model pred 0.0855 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني عند التقدم والا كفاك اللہ ان ستبقي اسمعك
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.1192 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني رغم ان تعود لله مسافر موجعه
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.1662 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك ربي لن يضل عند دعم عنك كي تعود صباح الطمانينه
# epsilon: 3.0
# | It  1 | dis model pred 0.0277 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني عند التقدم والا كفاك اللہ ان ستبقي اسمعك
# epsilon: 2.7
# | It  2 | dis model pred 0.0692 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني عند التقدم والا كفاك اللہ ان ستبقي اسمعك
# epsilon: 2.43
# | It  3 | dis model pred 0.1255 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك ربي لن يضل عند دعم عنك كي تعود صباح الطمانينه
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.2114 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك لن ادعو لك الوقت في والارض كي يخلق عنك نحو المحادثه
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.3210 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك لن يضل عند يقين ان اول لك كي احتاجك لنفسي
# epsilon: 4.0
# | It  1 | dis model pred 0.0277 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني عند التقدم والا كفاك اللہ ان ستبقي اسمعك
# epsilon: 3.6
# | It  2 | dis model pred 0.0904 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك طريق كي لن يخلق لك ذنبي بان تعود عند الله تحبه حين تغفو بگ نحو التقدم
# epsilon: 3.24
# | It  3 | dis model pred 0.1832 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك لن يضل عند يقين ان اول لك كي احتاجك لنفسي
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.3520 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك لذلك لا يدري بان لك نحو السماء والارض لن اخبر ربك عليه ليكون انها بجانبي
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.5183 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند قصد انتظر اول الشجره
# epsilon: 5.0
# | It  1 | dis model pred 0.0277 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني عند التقدم والا كفاك اللہ ان ستبقي اسمعك
# epsilon: 4.5
# | It  2 | dis model pred 0.1116 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك ربي لن يضل عند دعم ان تعود يوما للسعاده
# epsilon: 4.05
# | It  3 | dis model pred 0.2795 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه لك كي <UNK> عنك شيئا تحبه كي لن تعود ليكون لك اكثر من العنوان user
# epsilon: 3.645
# | It  4 | dis model pred 0.5229 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند قصد num عسي الله ان يريح
# epsilon: 3.2805
# | It  5 | dis model pred 0.6305 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند قصد num عسي الله ان يريح
# epsilon: 6.0
# | It  1 | dis model pred 0.0277 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي يعجبني عند التقدم والا كفاك اللہ ان ستبقي اسمعك
# epsilon: 5.4
# | It  2 | dis model pred 0.1374 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك لن ادعو لك الوقت في والارض كي يخلق عنك نحو المحادثه
# epsilon: 4.86
# | It  3 | dis model pred 0.3799 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند قصد num عسي الله ان يريح
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.5974 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند قصد num عسي الله ان يريح
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.6854 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند الابد num صباح التوكل عنها
# epsilon: 7.0
# | It  1 | dis model pred 0.0277 |
# لعل الله تصبح كل شيء جميلا لا قسي قلبك عني لك قلبك كي لن يخلق لك تحبه كي لن ياخذه الالم هيبقي اكثر منك عسي ان تعود
# epsilon: 6.3
# | It  2 | dis model pred 0.1693 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك لن ادعو لك الوقت في والارض ان اعشق العسر وحزنك نحو ربك
# epsilon: 5.67
# | It  3 | dis model pred 0.5217 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند قصد num عسي الله ان معااك
# epsilon: 5.103
# | It  4 | dis model pred 0.6805 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه كي لك عسي ان يمسك ضرر لن يخلق لك نحو قلبك كي تنتهي والكثير اليك
# epsilon: 4.5927
# | It  5 | dis model pred 0.7460 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه لك كي لا يخلق لك بصدق كفاك الله وكيف اعرف ان جدا نحو الحلم والارض
# epsilon: 8.0
# | It  1 | dis model pred 0.0277 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك لن يضل عند يقين ان اول لك كي احتاجك لنفسي
# epsilon: 7.2
# | It  2 | dis model pred 0.2055 |
# لعل الله تصبح كل شيء جميلا علي قلبك قسي قلبك كي لا تحبه وقل لك لن ادعو لك ان عند التقدم نحو ربك كي احتاجك
# epsilon: 6.48
# | It  3 | dis model pred 0.5961 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه يتبعه <UNK> لك كي تحبه كي لن يخلق لك شيئا عند ان يمسك هذا التوكل d
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.7195 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه لك كي لا يخلق لك بصدق كفاك الله وكيف اعرف ان جدا نحو الحلم والارض
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.7812 |
# لعل الله تصبح كل شيء جميلا علي قلبك بغير قادر اكتبه لك كي لا يخلق لك بصدق نحو السماء والارض لكان ان المواطن لن تخيب عنك
# ------------7------------
# الي بريطانيا باذن الله استودعكم الله
# origin_labels tensor([[0.]], device='cuda:0')
# الي خدمه <UNK> الشرق الاوسط وان شاء الله تف ايه ايضا <UNK> قبل الصور
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.1366 |
# في ال hash اوه <UNK> الله ونعم الوكيل قبل انتهاء لو <UNK> واحد الاخلاق يفارق الجماعه num
# epsilon: 1.8
# | It  2 | dis model pred 0.3807 |
# في ال hash لانني احلف <UNK> الله ومن رباك جدا احنا <UNK> علي الكرسي
# epsilon: 1.62
# | It  3 | dis model pred 0.5264 |
# في ال hash لانني احلف <UNK> الله ومن رباك جدا احنا <UNK> علي الكرسي
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.5654 |
# في ال hash لانني احلف <UNK> الله ومن رباك جدا احنا <UNK> علي الكرسي
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.5947 |
# في ال hash لانني احلف الله ومن اهل فخرا رسول الله و <UNK> الصح
# epsilon: 3.0
# | It  1 | dis model pred 0.1366 |
# في ال hash اوه <UNK> الله ونعم الوكيل قبل انتهاء لو <UNK> واحد الاخلاق
# epsilon: 2.7
# | It  2 | dis model pred 0.4876 |
# في ال hash لانني احلف <UNK> الله ومن رباك جدا احنا <UNK> علي الكرسي
# epsilon: 2.43
# | It  3 | dis model pred 0.5780 |
# في ال hash لانني احلف الله ومن اهل فخرا رسول الله و <UNK> الصح
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.6221 |
# في ال hash لانني احلف الله من كل سنه وتم العيال num صح <UNK> نفس الحديث الي morning
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.6554 |
# في ال hash اوه <UNK> الله ونعم الوكيل قال قبل انتهاء الطريقه <UNK> كلنا كريم
# epsilon: 4.0
# | It  1 | dis model pred 0.1366 |
# في ال hash لانني احلف <UNK> الله ومن احب العبقريه الوحيد num الي قصر <UNK>
# epsilon: 3.6
# | It  2 | dis model pred 0.5516 |
# في ال hash لانني احلف <UNK> الله ومن احب العبقريه الوحيد num الي قصر <UNK>
# epsilon: 3.24
# | It  3 | dis model pred 0.6292 |
# في ال hash بعدين يسالوني الله من ايديك فهو <UNK> ليس مع الموت hash
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.7530 |
# في ال hash بعدين يسالوني ان الله يلعن منه اكيد خربت <UNK>
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.8812 |
# في ال hash بعدين يسالوني ان الله يلعن منه اكيد خربت <UNK>
# epsilon: 5.0
# | It  1 | dis model pred 0.1366 |
# في ال hash لانني احلف <UNK> الله ومن احب العبقريه الوحيد num الي قصر <UNK>
# epsilon: 4.5
# | It  2 | dis model pred 0.5836 |
# في ال hash اوه <UNK> الله تعالي قبل منتج كان الجزيره جيدا
# epsilon: 4.05
# | It  3 | dis model pred 0.6784 |
# في ال hash بعدين يسالوني الله من ايديك فهو <UNK> ليس مع الموت hash
# epsilon: 3.645
# | It  4 | dis model pred 0.8084 |
# في ال hash بعدين يسالوني الله من ايديك فهو <UNK> ياخي هو الازمه
# epsilon: 3.2805
# | It  5 | dis model pred 0.9054 |
# في ال hash بعدين يسالوني الله اللي قدم اكيد روش <UNK> فيها انا
# epsilon: 6.0
# | It  1 | dis model pred 0.1366 |
# في ال hash لانني احلف <UNK> الله ومن احب العبقريه الوحيد num الي قصر <UNK>
# epsilon: 5.4
# | It  2 | dis model pred 0.5896 |
# في ال hash لانني احلف الله ومن اهل فخرا رسول الله الصح
# epsilon: 4.86
# | It  3 | dis model pred 0.7055 |
# في ال hash بعدين تتميز <UNK> منك الله ان السؤال الوحيد اللي اتعود علي <UNK> عليكم
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.8513 |
# في ال hash بعدين تتميز <UNK> منك الله ان الطالب والتفكير بدون حاجه <UNK>
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.9096 |
# في ال hash بعدين يسالوني الله من ايديك وانما هو امه <UNK>
# epsilon: 7.0
# | It  1 | dis model pred 0.1366 |
# في ال hash لانني <UNK> وانت يعافيك الله و اليوم بناء دوله <UNK>
# epsilon: 6.3
# | It  2 | dis model pred 0.5893 |
# في ال hash بحيث تقول الله معك الذين كتمت من النهار وكان الله تعالي <UNK> المصريه
# epsilon: 5.67
# | It  3 | dis model pred 0.7621 |
# في ال hash بعدين يسالوني الله من ايديك وانما <UNK> ليس زي النبي صلي الله عليه وسلم
# epsilon: 5.103
# | It  4 | dis model pred 0.9160 |
# في ال hash يالهوي جدا اي عمل السعااده سبحان الله للاسف الثوره
# epsilon: 4.5927
# | It  5 | dis model pred 0.9329 |
# في ال hash يالهوي جدا اي عمل البرسا كلنا بعد ما سلاما
# epsilon: 8.0
# | It  1 | dis model pred 0.1366 |
# في ال hash لانني <UNK> وانت يعافيك الله و اليوم بناء دوله <UNK>
# epsilon: 7.2
# | It  2 | dis model pred 0.5818 |
# في ال hash بحيث تقول الله معك الذين كتمت من النهار وكان الله تعالي <UNK> المصريه
# epsilon: 6.48
# | It  3 | dis model pred 0.7853 |
# في ال hash يالهوي لكن الله اسالك من الخبره ماشاء الله فقط
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.9414 |
# في ال hash يالهوي لكن الله اسالك من الخبره ماشاء الله فقط
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.9582 |
# في ال hash يالهوي لكن الله اسالك من النتيجه رجا دا لو <UNK>
# ------------8------------
# الابتسامہ كانت صدقه ف اصبحت في مجتمعنا شيء يثير الشك داخل الاخرين num
# origin_labels tensor([[0.]], device='cuda:0')
# كانت الابتسامہ ب الامارات ف هذا ما تنطق خدمه العملاء داخل قلبك الشك لن يدخل num lt num
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.3009 |
# كانت الابتسامہ ب الامارات ف هذا ما تنطق خدمه العملاء داخل قلبك الشك لن تتعلم مننا hash num
# epsilon: 1.8
# | It  2 | dis model pred 0.4542 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 1.62
# | It  3 | dis model pred 0.5588 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.6212 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.6638 |
# كانت الابتسامہ ب الامارات في هذا احيان اتعود علي حق الشك يمكن تكون تجاره مدينه زباله num hash
# epsilon: 3.0
# | It  1 | dis model pred 0.3009 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 2.7
# | It  2 | dis model pred 0.5323 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 2.43
# | It  3 | dis model pred 0.6394 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.7042 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل رحله التفكير كثيرا num hash
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.7464 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل رحله التفكير num hash
# epsilon: 4.0
# | It  1 | dis model pred 0.3009 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 3.6
# | It  2 | dis model pred 0.5938 |
# كانت الابتسامہ ب الامارات في هذا احيان اتعود علي حق الشك يمكن تكون تجاره مدينه زباله num hash
# epsilon: 3.24
# | It  3 | dis model pred 0.7051 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل رحله التفكير كثيرا num hash
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.7644 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم باقي الاخرين num
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.8008 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم باقي الاخرين num
# epsilon: 5.0
# | It  1 | dis model pred 0.3009 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 4.5
# | It  2 | dis model pred 0.6483 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل رحله التفكير كثيرا num hash
# epsilon: 4.05
# | It  3 | dis model pred 0.7557 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 3.645
# | It  4 | dis model pred 0.8083 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 3.2805
# | It  5 | dis model pred 0.8377 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 6.0
# | It  1 | dis model pred 0.3009 |
# كانت الابتسامہ ب الامارات في هذا احيان تندم علي حركه مكان الشك هم ال داخل الاخرين num
# epsilon: 5.4
# | It  2 | dis model pred 0.6967 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل رحله التفكير كثيرا num hash
# epsilon: 4.86
# | It  3 | dis model pred 0.7943 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.8382 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.8627 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 7.0
# | It  1 | dis model pred 0.3009 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل رحله التفكير كثيرا num hash
# epsilon: 6.3
# | It  2 | dis model pred 0.7407 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 5.67
# | It  3 | dis model pred 0.8264 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل الندم مش قليل num hash
# epsilon: 5.103
# | It  4 | dis model pred 0.8599 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك الناجح لكن تكون مريض نتكلم بنفسك num hash
# epsilon: 4.5927
# | It  5 | dis model pred 0.8818 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك الناجح لكن تكون مريض نتكلم بنفسك num hash
# epsilon: 8.0
# | It  1 | dis model pred 0.3009 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك والاستقرار وهو حاجه داخل رحله التفكير كثيرا num hash
# epsilon: 7.2
# | It  2 | dis model pred 0.7802 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك الناجح لكن تكون مريض نتكلم بنفسك num hash
# epsilon: 6.48
# | It  3 | dis model pred 0.8488 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك الناجح لكن تكون مريض نتكلم بنفسك num hash
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.8790 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك الناجح لكن تكون مريض نتكلم بنفسك num hash
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.8977 |
# كانت الفضفضه ب قلبي اصبحت في اي حركه الشك الناجح لكن تكون مريض نتكلم بنفسك num hash
# ------------9------------
# اللهم num في يوم الجمعه اجمع قلوبنا علي طاعتك و اجمع نفوسنا علي خشيتك و اجمع ارواحنا في جنتك
# origin_labels tensor([[0.]], device='cuda:0')
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع نفوسنا علي خشيتك
# target_labels tensor([[1.]], device='cuda:0')
# gold:
# epsilon: 2.0
# | It  1 | dis model pred 0.1117 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع نفوسنا علي خشيتك
# epsilon: 1.8
# | It  2 | dis model pred 0.2723 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 1.62
# | It  3 | dis model pred 0.5137 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 1.4580000000000002
# | It  4 | dis model pred 0.6599 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 1.3122000000000003
# | It  5 | dis model pred 0.8054 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 3.0
# | It  1 | dis model pred 0.1117 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع نفوسنا علي خشيتك
# epsilon: 2.7
# | It  2 | dis model pred 0.3781 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 2.43
# | It  3 | dis model pred 0.7012 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 2.1870000000000003
# | It  4 | dis model pred 0.8703 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 1.9683000000000004
# | It  5 | dis model pred 0.9059 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 4.0
# | It  1 | dis model pred 0.1117 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 3.6
# | It  2 | dis model pred 0.4905 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 3.24
# | It  3 | dis model pred 0.8324 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 2.9160000000000004
# | It  4 | dis model pred 0.9213 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 2.6244000000000005
# | It  5 | dis model pred 0.9459 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 5.0
# | It  1 | dis model pred 0.1117 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 4.5
# | It  2 | dis model pred 0.6019 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 4.05
# | It  3 | dis model pred 0.9235 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 3.645
# | It  4 | dis model pred 0.9540 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 3.2805
# | It  5 | dis model pred 0.9645 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 6.0
# | It  1 | dis model pred 0.1117 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> رب
# epsilon: 5.4
# | It  2 | dis model pred 0.7218 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> القدر
# epsilon: 4.86
# | It  3 | dis model pred 0.9604 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي النسيان
# epsilon: 4.3740000000000006
# | It  4 | dis model pred 0.9705 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي نفسه
# epsilon: 3.9366000000000008
# | It  5 | dis model pred 0.9758 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي نفسه
# epsilon: 7.0
# | It  1 | dis model pred 0.1117 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> القدر
# epsilon: 6.3
# | It  2 | dis model pred 0.8263 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> القدر
# epsilon: 5.67
# | It  3 | dis model pred 0.9695 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي النسيان
# epsilon: 5.103
# | It  4 | dis model pred 0.9767 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي نفسه
# epsilon: 4.5927
# | It  5 | dis model pred 0.9807 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك <UNK> و اجمع منا علي يقين
# epsilon: 8.0
# | It  1 | dis model pred 0.1117 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> القدر
# epsilon: 7.2
# | It  2 | dis model pred 0.9009 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> القدر
# epsilon: 6.48
# | It  3 | dis model pred 0.9674 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي نفسه
# epsilon: 5.832000000000001
# | It  4 | dis model pred 0.9761 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي نفسه
# epsilon: 5.248800000000001
# | It  5 | dis model pred 0.9800 |
# اللهم في يوم num اجمع قلوبنا علي طاعتك و نفوسنا علي خشيتك و اجمع ارواحنا في جنتك و اجمع <UNK> زي نفسه

# %%
print(ae_model)
# Out:
# EncoderDecoder(
#   (encoder): Encoder(
#     (layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linears): ModuleList(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): Linear(in_features=256, out_features=256, bias=True)
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=1024, bias=True)
#           (w_2): Linear(in_features=1024, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (sublayer): ModuleList(
#           (0): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): EncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linears): ModuleList(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): Linear(in_features=256, out_features=256, bias=True)
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=1024, bias=True)
#           (w_2): Linear(in_features=1024, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (sublayer): ModuleList(
#           (0): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (norm): LayerNorm()
#   )
#   (decoder): Decoder(
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linears): ModuleList(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): Linear(in_features=256, out_features=256, bias=True)
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (src_attn): MultiHeadedAttention(
#           (linears): ModuleList(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): Linear(in_features=256, out_features=256, bias=True)
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=1024, bias=True)
#           (w_2): Linear(in_features=1024, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (sublayer): ModuleList(
#           (0): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): DecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linears): ModuleList(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): Linear(in_features=256, out_features=256, bias=True)
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (src_attn): MultiHeadedAttention(
#           (linears): ModuleList(
#             (0): Linear(in_features=256, out_features=256, bias=True)
#             (1): Linear(in_features=256, out_features=256, bias=True)
#             (2): Linear(in_features=256, out_features=256, bias=True)
#             (3): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=1024, bias=True)
#           (w_2): Linear(in_features=1024, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (sublayer): ModuleList(
#           (0): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): SublayerConnection(
#             (norm): LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (norm): LayerNorm()
#   )
#   (src_embed): Sequential(
#     (0): Embeddings(
#       (lut): Embedding(41286, 256)
#     )
#     (1): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (tgt_embed): Sequential(
#     (0): Embeddings(
#       (lut): Embedding(41286, 256)
#     )
#     (1): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (generator): Generator(
#     (proj): Linear(in_features=256, out_features=41286, bias=True)
#   )
#   (position_layer): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (sigmoid): Sigmoid()
# )
